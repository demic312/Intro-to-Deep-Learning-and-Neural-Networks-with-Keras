# %% [markdown]
# <h1 align = center><font size = 10>Build a Regression Model in Keras</font></h1>
# <h2 align = center><font size = 6>Part D: Increase the Number of Hidden Layers</font></h2>

# %% [markdown]
# ## Introduction
#
# In this course project, we will build a regression model using the deep learning Keras library to model the data about concrete compressive strength. We will experiment with increasing the number of training epochs and changing number of hidden layers, and we will see how changing these parameters impacts the performance of the model.

# %% [markdown]
# ## Objectives for this Notebook
#
# Use the Keras library to build a neural network with **3 hidden layer** of **10 nodes** with **relu** activation function, the **adam** optimizer, and the **mean_squared_error** loss function, with consists of:
# 1. Randomly split the **normalized** data into training and test sets by holding 30% of the data for testing. We can use the train_test_split helper function from sklearn.
# 2. Train the model on the training data using **50 epochs**.
# 3. Evaluate the model on the test data and compute the mean square error between the predicted concrete strength and the actual concrete strength. We can use the **mean_squared_error** function from sklearn.
# 4. Repeat steps 1-3, **50 times**, and create a list of **50** mean squared errors.
# 5. Report the mean and the standard deviation of the mean squared errors.

# %% [markdown]
# ## Table of Contents
#
# 1. Import Packages
# 2. Import Data
# 3. Visualize Data
# 4. Split Data into Predictors and Target
# 5. Normalize Data
# 6. Create Network Initialization Function
# 7. Iterate Core Loop
# 8. Report Statistics
# 9. Discussions

# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from IPython.display import display
# %matplotlib inline

# %% [markdown]
# ## Import Data

# %%
concrete_df = pd.read_csv("Data/concrete_data.csv")
display(concrete_df.head())
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# #### About this Dataset
#
# The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:
#
# 1. Cement
# 2. Blast Furnace Slag
# 3. Fly Ash
# 4. Water
# 5. Superplasticizer
# 6. Coarse Aggregate
# 7. Fine Aggregate

# %% [markdown]
# ## Visualize Data
#
# #### Print Shape

# %%
print(concrete_df.shape)
# Out:
# (1030, 9)

# %% [markdown]
# #### Describe Data

# %%
display(concrete_df.describe())
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %% [markdown]
# #### Check Null Values

# %%
display(concrete_df.isnull().sum())
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# ## Split Data into Predictors and Target

# %%
concrete_columns = concrete_df.columns
predictors_df = concrete_df[concrete_columns[concrete_columns != 'Strength']]
num_predictors = predictors_df.shape[1]
target = concrete_df['Strength']
target_df = pd.DataFrame(target)
target_df.set_axis(['Strength'], axis = 1, inplace = True)

print("Predictors:")
display(predictors_df.head())
print()
print("Target:")
display(target_df.head())
# Out:
# Predictors:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360
# Target:
#    Strength
# 0     79.99
# 1     61.89
# 2     40.27
# 3     41.05
# 4     44.30

# %% [markdown]
# ## Normalize Data

# %%
predictors_normalized_df = (predictors_df - predictors_df.mean()) / predictors_df.std()
display(predictors_normalized_df.head())
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# ## Create Network Initialization Function

# %%
def regression_model():
    output_model = Sequential()
    output_model.add(Dense(10, activation = 'relu', input_shape = (num_predictors,)))
    output_model.add(Dense(10, activation = 'relu'))
    output_model.add(Dense(10, activation = 'relu'))
    output_model.add(Dense(1))

    output_model.compile(optimizer ='adam', loss ='mean_squared_error')
    return output_model

# %% [markdown]
# ## Iterate Core Loop

# %%
mean_squared_errors_df = pd.DataFrame(np.zeros((50, 3)))
mean_squared_errors_df.set_axis(['MSE', 'RMSE', 'STD'], axis = 1, inplace = True)

for i in range(50):
    x_train, x_test, y_train, y_test = train_test_split(predictors_normalized_df, target_df, test_size = 0.3, random_state = i)

    model = regression_model()
    model.fit(x_train, y_train, validation_split = 0.3, epochs = 50, verbose = 0)

    y_hat = model.predict(x_test)
    mean_squared_errors_df.at[i, 'MSE'] = mean_squared_error(y_test, y_hat, squared = True)
    mean_squared_errors_df.at[i, 'RMSE'] = np.sqrt(mean_squared_errors_df['MSE'][i])
    mean_squared_errors_df.at[i, 'STD'] = np.std(np.abs(y_hat - y_test)) / np.sqrt(y_hat.shape[0])

display(mean_squared_errors_df)
# Out:
# Metal device set to: Apple M1 Max
# 2022-04-08 17:54:49.413974: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-04-08 17:54:49.414097: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2022-04-08 17:54:49.970253: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-04-08 17:54:50.143165: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:54:52.170333: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:54:56.971550: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:54:57.200780: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:54:57.392777: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:01.873361: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:02.077346: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:02.277688: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:06.734368: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:06.924012: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:07.118390: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:11.577238: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:11.772262: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:11.968171: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:16.409956: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:16.888792: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:17.098879: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:21.680541: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:21.882121: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:22.087376: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:26.578440: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:26.773943: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:26.960245: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:31.330786: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:31.519158: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:31.710608: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:36.077902: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:36.270288: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:36.460249: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:40.905136: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:41.377256: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:41.578658: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:46.150162: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:46.346269: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:46.548075: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:50.995772: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:51.179848: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:51.364767: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:55.883292: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:56.087576: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:55:56.279375: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:00.890753: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:01.081790: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:01.278481: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:05.866337: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:06.059192: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:06.248528: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:10.590546: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:10.780240: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:10.972665: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:15.345204: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:15.540133: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:15.729765: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:20.117191: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:20.310370: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:20.508517: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:24.925231: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:25.363536: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:25.554117: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:30.064349: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:30.275065: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:30.466621: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:35.278780: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:35.499429: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:35.699689: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:40.339651: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:40.528000: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:40.723078: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:45.160668: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:45.348355: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:45.543975: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:49.938130: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:50.369306: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:50.558288: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:54.937083: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:55.127337: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:55.317420: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:59.720630: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:56:59.907273: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:00.098162: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:04.531992: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:04.721521: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:04.913136: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:09.314034: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:09.502455: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:09.708290: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:14.282455: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:14.467596: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:14.658223: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:19.013335: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:19.205206: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:19.396169: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:24.040655: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:24.239343: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:24.439538: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:28.900833: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:29.086617: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:29.278313: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:36.345508: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:36.828180: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:37.023545: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:41.687357: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:41.891948: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:42.117214: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:46.743304: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:46.954797: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:47.182816: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:51.720479: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:51.912170: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:52.108038: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:56.591431: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:57.012760: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:57:57.203033: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:01.588490: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:01.779675: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:01.975117: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:06.468504: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:06.660092: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:06.861175: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:11.331367: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:11.525148: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:11.730703: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:16.211968: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:16.407622: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:16.608582: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:20.982466: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:21.441477: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:21.632555: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:26.022250: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:26.214759: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:26.410060: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:30.832844: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:31.025048: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:31.227327: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:35.626005: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:35.817298: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:36.018063: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:40.438787: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:40.635309: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:40.837168: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:45.469680: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:45.660806: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:45.858193: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:50.234292: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:50.425112: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:50.627579: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:55.050279: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:55.246139: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:55.444102: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-08 17:58:59.898753: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
#            MSE       RMSE       STD
# 0   132.710259  11.519994  0.372817
# 1   160.376134  12.663970  0.413767
# 2   134.802719  11.610457  0.366975
# 3   153.876807  12.404709  0.395123
# 4   151.730054  12.317875  0.392741
# 5   148.030914  12.166796  0.393617
# 6   173.437813  13.169579  0.432440
# 7   133.610739  11.559011  0.389603
# 8   147.758673  12.155603  0.391922
# 9   133.502243  11.554317  0.363463
# 10  132.230748  11.499163  0.371218
# 11  133.134243  11.538381  0.369041
# 12  149.773859  12.238213  0.401636
# 13  164.695060  12.833357  0.437832
# 14  146.230500  12.092580  0.385234
# 15  149.923416  12.244322  0.420972
# 16  123.730582  11.123425  0.366432
# 17  143.705607  11.987727  0.389019
# 18  123.924519  11.132139  0.359840
# 19  146.004516  12.083233  0.390228
# 20  139.493693  11.810745  0.371772
# 21  142.108937  11.920945  0.391767
# 22  138.354553  11.762421  0.368248
# 23  140.232697  11.841989  0.392597
# 24  133.301778  11.545639  0.394687
# 25  136.669650  11.690580  0.392784
# 26  160.095834  12.652898  0.394275
# 27  147.189337  12.132161  0.396639
# 28  147.343603  12.138517  0.393250
# 29  145.415611  12.058840  0.391335
# 30  173.841198  13.184885  0.432881
# 31  130.960580  11.443801  0.384728
# 32  181.237973  13.462465  0.457177
# 33  133.687277  11.562321  0.388275
# 34  137.784980  11.738185  0.362066
# 35  153.264133  12.379989  0.411031
# 36  146.444505  12.101426  0.400461
# 37  148.440852  12.183630  0.396557
# 38  142.812285  11.950409  0.386386
# 39  155.674822  12.476972  0.425350
# 40  151.875769  12.323789  0.411309
# 41  146.851565  12.118233  0.385055
# 42  133.780300  11.566343  0.366835
# 43  144.334521  12.013930  0.384676
# 44  138.479166  11.767717  0.392208
# 45  148.506202  12.186312  0.420602
# 46  144.143702  12.005986  0.384641
# 47  160.855729  12.682891  0.421435
# 48  136.968841  11.703369  0.398218
# 49  151.016107  12.288861  0.385675

# %% [markdown]
# ## Report Statistics
#
# #### Describe Statistics

# %%
display(mean_squared_errors_df.describe())
# Out:
#               MSE       RMSE        STD
# count   50.000000  50.000000  50.000000
# mean   145.487112  12.051822   0.393737
# std     12.112200   0.495590   0.021160
# min    123.730582  11.123425   0.359840
# 25%    136.744448  11.693777   0.384689
# 50%    145.710064  12.071036   0.392065
# 75%    150.742934  12.277726   0.399901
# max    181.237973  13.462465   0.457177

# %% [markdown]
# #### Plot RMSE

# %%
plt.plot(range(50), mean_squared_errors_df['RMSE'], 'g')
plt.fill_between(range(50), mean_squared_errors_df['RMSE'] - mean_squared_errors_df['STD'], mean_squared_errors_df['RMSE'] + mean_squared_errors_df['STD'], alpha = 0.1)
plt.fill_between(range(50), mean_squared_errors_df['RMSE'] - 3 * mean_squared_errors_df['STD'], mean_squared_errors_df['RMSE'] + 3 * mean_squared_errors_df['STD'], alpha = 0.1, color = 'green')
plt.title('RMSE by random_state')
plt.legend(('RMSE', '+/- 1 std', '+/- 3 std'))
plt.ylabel('RMSE')
plt.xlabel('random_state')
plt.show()

# %% [markdown]
# ## Discussions
#
# As expected, increasing the complexity of the network decreased the root mean squared error dramatically. However, networks with greater complexity may also lead to greater difficulty in training, so the complexity of the network may present an interaction effect with the number of epochs.
